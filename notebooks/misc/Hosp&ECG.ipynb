# %%
import pandas as pd
import wfdb
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path
import seaborn as sns
from scipy.signal import butter, filtfilt, iirnotch
import copy

# %%
BASE = Path("mimic-iv-ecg-demo-data")
DIAG_PATH = "/Users/shruti14/Desktop/ClinicalDigitalTwin/hosp_diagnosis.csv"
MEAS_PATH = "/Users/shruti14/Desktop/ClinicalDigitalTwin/machine_measurements.csv"

# %%
df_diag = pd.read_csv(DIAG_PATH)
df_ecg = pd.read_csv(BASE / "record_list.csv")
temp = pd.read_csv(MEAS_PATH, nrows=5)
report_cols = [col for col in temp.columns if col.startswith("report_") or col in ["filtering"]]
dtype_map = {col: "string" for col in report_cols}
df_meas = pd.read_csv(MEAS_PATH, dtype=dtype_map, low_memory=False)

# %%
diag_text = (
    df_diag.groupby("subject_id")["long_title"]
           .apply(lambda x: " ; ".join(x.unique()))
           .reset_index()
)

# %%
def flag_dx(df):
    # Example high-yield conditions
    afib = {"42731","I48","I480","I481","I482","I4891"}
    htn  = {"4010","4011","4019","I10"}
    cad  = {"4140","I25","I2510","I25119"}
    hf   = {"4280","I50","I500","I5030"}
    dm   = {"25000","E10","E11"}

    df["afib"] = df["icd_code"].astype(str).isin(afib).astype(int)
    df["htn"]  = df["icd_code"].astype(str).isin(htn).astype(int)
    df["cad"]  = df["icd_code"].astype(str).isin(cad).astype(int)
    df["hf"]   = df["icd_code"].astype(str).isin(hf).astype(int)
    df["dm"]   = df["icd_code"].astype(str).isin(dm).astype(int)

    return df

df_diag = flag_dx(df_diag)

# %%
diag_flags = (
    df_diag.groupby("subject_id")[["afib","htn","cad","hf","dm"]]
           .max()
           .reset_index()
)

# %%
ecg_grouped = (
    df_ecg.groupby("subject_id")["path"]
           .apply(list)
           .reset_index()
)

# %%
df_meas.columns.tolist()
# Out:
# ['subject_id',
#  'study_id',
#  'cart_id',
#  'ecg_time',
#  'report_0',
#  'report_1',
#  'report_2',
#  'report_3',
#  'report_4',
#  'report_5',
#  'report_6',
#  'report_7',
#  'report_8',
#  'report_9',
#  'report_10',
#  'report_11',
#  'report_12',
#  'report_13',
#  'report_14',
#  'report_15',
#  'report_16',
#  'report_17',
#  'bandwidth',
#  'filtering',
#  'rr_interval',
#  'p_onset',
#  'p_end',
#  'qrs_onset',
#  'qrs_end',
#  't_end',
#  'p_axis',
#  'qrs_axis',
#  't_axis']

# %%
df_meas
# Out:
#         subject_id  study_id  cart_id             ecg_time  \
# 0         10000032  40689238  6848296  2180-07-23 08:44:00
# 1         10000032  44458630  6848296  2180-07-23 09:54:00
# 2         10000032  49036311  6376932  2180-08-06 09:07:00
# 3         10000117  45090959  6214760  2181-03-04 17:14:00
# 4         10000117  48446569  6632385  2183-09-18 13:52:00
# ...            ...       ...      ...                  ...
# 800030    19999840  48683947  6283529  2164-09-12 12:28:00
# 800031    19999840  41842293  6947865  2164-09-17 11:31:00
# 800032    19999987  41190887  6848296  2145-11-02 19:54:00
# 800033    19999987  45828463  6315641  2145-11-03 03:00:00
# 800034    19999987  49815090  6315641  2145-11-03 08:47:00
#
#                                    report_0  \
# 0                              Sinus rhythm
# 1                              Sinus rhythm
# 2                         Sinus tachycardia
# 3                              Sinus rhythm
# 4                              Sinus rhythm
# ...                                     ...
# 800030                        Sinus rhythm.
# 800031  Accelerated idioventricular rhythm.
# 800032       Sinus tachycardia with PVC(s).
# 800033                        Sinus rhythm.
# 800034                        Sinus rhythm.
#
#                                                 report_1  \
# 0                      Possible right atrial abnormality
# 1                      Possible right atrial abnormality
# 2                                                   <NA>
# 3                                                   <NA>
# 4                                                   <NA>
# ...                                                  ...
# 800030                               Left axis deviation
# 800031                               Left axis deviation
# 800032                 Possible right atrial abnormality
# 800033                                              <NA>
# 800034  Possible anteroseptal infarct - age undetermined
#
#                                                  report_2  \
# 0                                                    <NA>
# 1                                                    <NA>
# 2                              Normal ECG except for rate
# 3                                              Normal ECG
# 4                                                    <NA>
# ...                                                   ...
# 800030                                               <NA>
# 800031                               IV conduction defect
# 800032  Inferior and lateral ST elevation - possible e...
# 800033                                         Normal ECG
# 800034                                               <NA>
#
#                                    report_3  \
# 0                            Borderline ECG
# 1                            Borderline ECG
# 2                                      <NA>
# 3                                      <NA>
# 4                                      <NA>
# ...                                     ...
# 800030                       Borderline ECG
# 800031  Inferior infarct - age undetermined
# 800032                                 <NA>
# 800033                                 <NA>
# 800034                         Abnormal ECG
#
#                                                  report_4  \
# 0                                                    <NA>
# 1                                                    <NA>
# 2                                                    <NA>
# 3                                                    <NA>
# 4                                                    <NA>
# ...                                                   ...
# 800030                                               <NA>
# 800031  Ant/septal and lateral ST-T changes suggest my...
# 800032                                     Borderline ECG
# 800033                                               <NA>
# 800034                                               <NA>
#
#                               report_5  ...                    filtering  \
# 0                                 <NA>  ...  60 Hz notch Baseline filter
# 1                                 <NA>  ...  60 Hz notch Baseline filter
# 2                                 <NA>  ...  60 Hz notch Baseline filter
# 3                                 <NA>  ...  60 Hz notch Baseline filter
# 4                                 <NA>  ...              <not specified>
# ...                                ...  ...                          ...
# 800030                            <NA>  ...  60 Hz notch Baseline filter
# 800031  Low QRS voltages in limb leads  ...  60 Hz notch Baseline filter
# 800032                            <NA>  ...  60 Hz notch Baseline filter
# 800033                            <NA>  ...  60 Hz notch Baseline filter
# 800034                            <NA>  ...  60 Hz notch Baseline filter
#
#        rr_interval p_onset  p_end qrs_onset qrs_end t_end p_axis qrs_axis  \
# 0              659      40    128       170     258   518     81       77
# 1              722      40    124       162     246   504     77       75
# 2              600      40    130       162     244   474     79       72
# 3              659      40    146       180     254   538     79       66
# 4              659     368  29999       504     590   868     84       80
# ...            ...     ...    ...       ...     ...   ...    ...      ...
# 800030         659      40    154       182     266   560     38      -39
# 800031         967   29999  29999       200     350   688  29999      -80
# 800032         526      40    148       204     286   528     58       50
# 800033         631      40    156       202     282   570     59       54
# 800034         689      40    156       206     284   594     55       56
#
#        t_axis
# 0          79
# 1          70
# 2          77
# 3          69
# 4          77
# ...       ...
# 800030     35
# 800031    174
# 800032     51
# 800033     56
# 800034     52
#
# [800035 rows x 33 columns]

# %%
# Identify report columns
report_cols = [c for c in df_meas.columns if c.startswith("report_")]

df_meas[report_cols] = df_meas[report_cols].astype(str)

# Create one combined text per ECG
df_meas["full_report"] = df_meas[report_cols].apply(
    lambda row: " ".join([x for x in row if x not in ["", "nan", "NaN"]]),
    axis=1
)

# Combine all ECG reports per subject
meas_reports = (
    df_meas.groupby("subject_id", as_index=False)
    .agg({"full_report": lambda x: " ".join(x)})
)

# %%
numeric_cols = [
    "rr_interval", "p_onset", "p_end",
    "qrs_onset", "qrs_end", "t_end",
    "p_axis", "qrs_axis", "t_axis"
]

numeric_cols = [c for c in numeric_cols if c in df_meas.columns]

# %%
meas_numeric = (
    df_meas.groupby("subject_id", as_index=False)
    .agg({
        **{col: ["mean", "std", "min", "max"] for col in numeric_cols},
        "study_id": "nunique"   # number of ECGs
    })
)

# flatten multi-index columns
meas_numeric.columns = [
    "_".join(col).rstrip("_") 
    for col in meas_numeric.columns
]

# %%
# Start with diagnosis text + flags
merged = diag_text.merge(diag_flags, on="subject_id", how="outer")

# %%
# Add numeric ECG features
merged = merged.merge(meas_numeric, on="subject_id", how="outer")

# %%
# Add text ECG reports
merged = merged.merge(meas_reports, on="subject_id", how="outer")

# %%
# Add raw ECG paths
merged = merged.merge(ecg_grouped, on="subject_id", how="left")

# %%
merged = merged[merged["path"].notna()]
merged
# Out:
#       subject_id                                         long_title  afib  \
# 0       10000032  Portal hypertension ; Unspecified viral hepati...   0.0
# 26      10001217  Intracranial abscess ; Compression of brain ; ...   0.0
# 35      10001725  Other specified retention of urine ; Other ana...   0.0
# 55      10002428  Other drugs and medicinal substances causing a...   0.0
# 58      10002495  Non-ST elevation (NSTEMI) myocardial infarctio...   1.0
# ...          ...                                                ...   ...
# 981     10038999  Pneumonia, unspecified organism ; Displaced co...   0.0
# 1000    10039708  Fall (on) (from) other stairs and steps, initi...   0.0
# 1004    10039831  Secondary and unspecified malignant neoplasm o...   0.0
# 1012    10039997  Cerebral aneurysm, nonruptured ; Manic episode...   1.0
# 1013    10040025  Personal history of tobacco use ; Body Mass In...   1.0
#
#       htn  cad   hf   dm  rr_interval_mean  rr_interval_std  rr_interval_min  \
# 0     0.0  0.0  0.0  0.0        660.333333        61.010928            600.0
# 26    1.0  0.0  0.0  0.0        870.000000        35.355339            845.0
# 35    0.0  0.0  0.0  0.0       1016.000000              NaN           1016.0
# 55    1.0  0.0  1.0  0.0        669.400000       111.007593            508.0
# 58    1.0  1.0  0.0  0.0        551.333333       155.532419            394.0
# ...   ...  ...  ...  ...               ...              ...              ...
# 981   0.0  0.0  0.0  0.0        609.000000       159.987500            483.0
# 1000  1.0  0.0  0.0  0.0        841.750000       189.197780            612.0
# 1004  0.0  0.0  0.0  0.0        833.000000              NaN            833.0
# 1012  1.0  0.0  0.0  0.0        975.500000        10.606602            968.0
# 1013  0.0  1.0  1.0  1.0        776.058824       192.656258            483.0
#
#       ...  qrs_axis_std  qrs_axis_min  qrs_axis_max  t_axis_mean  t_axis_std  \
# 0     ...      2.516611          72.0          77.0    75.333333    4.725816
# 26    ...      4.949747           8.0          15.0    39.500000   12.020815
# 35    ...           NaN          45.0          45.0    45.000000         NaN
# 55    ...     27.354289         -48.0          42.0    43.933333   12.819999
# 58    ...     20.599353          10.0          51.0   -44.666667   18.502252
# ...   ...           ...           ...           ...          ...         ...
# 981   ...      6.082763          29.0          40.0    20.666667   16.165808
# 1000  ...     21.998485           6.0          90.0    18.562500   74.585940
# 1004  ...           NaN          21.0          21.0    37.000000         NaN
# 1012  ...     16.970563         -37.0         -13.0    96.000000   29.698485
# 1013  ...     12.845519           3.0          60.0    16.352941  106.339633
#
#       t_axis_min  t_axis_max  study_id_nunique  \
# 0           70.0        79.0               3.0
# 26          31.0        48.0               2.0
# 35          45.0        45.0               1.0
# 55          21.0        64.0              15.0
# 58         -66.0       -33.0               3.0
# ...          ...         ...               ...
# 981          2.0        30.0               3.0
# 1000       -90.0       168.0              16.0
# 1004        37.0        37.0               1.0
# 1012        75.0       117.0               2.0
# 1013      -166.0       172.0              17.0
#
#                                             full_report  \
# 0     Sinus rhythm Possible right atrial abnormality...
# 26    Sinus rhythm <NA> Normal ECG <NA> <NA> <NA> <N...
# 35    Sinus bradycardia <NA> Normal ECG except for r...
# 55    Sinus rhythm - supraventricular extrasystoles ...
# 58    Sinus tachycardia. Extensive ST-T changes sugg...
# ...                                                 ...
# 981   Sinus tachycardia. <NA> Normal ECG except for ...
# 1000  Sinus rhythm Septal T wave changes are nonspec...
# 1004  Sinus rhythm <NA> Normal ECG <NA> <NA> <NA> <N...
# 1012  Sinus rhythm with PVCs with borderline 1st deg...
# 1013  Sinus rhythm. ST junctional depression is nons...
#
#                                                    path
# 0     [files/p10000032/s107143276/107143276, files/p...
# 26    [files/p10001217/s105362569/105362569, files/p...
# 35               [files/p10001725/s102147240/102147240]
# 55    [files/p10002428/s104430624/104430624, files/p...
# 58    [files/p10002495/s107316808/107316808, files/p...
# ...                                                 ...
# 981   [files/p10038999/s109127970/109127970, files/p...
# 1000  [files/p10039708/s103786521/103786521, files/p...
# 1004             [files/p10039831/s106035722/106035722]
# 1012  [files/p10039997/s102298909/102298909, files/p...
# 1013  [files/p10040025/s103015046/103015046, files/p...
#
# [92 rows x 46 columns]

# %% [markdown]
# Step 1: Split dataset → train / val / test (subject-level) \
# Step 2: Preprocess numeric, text, waveform \
# Step 3: Encode features: \
#           - Tabular: StandardScaler \
#           - Text: ClinicalBERT embedding \
#           - Waveform: 1D CNN input \
# Step 4: Build model: \
#           - Option A: Tabular + Text embeddings → MLP \
#           - Option B: Waveform → CNN + concatenate with tabular/text → final MLP \
# Step 5: Train model \
# Step 6: Evaluate: AUROC, accuracy, F1, etc. \
# Step 7: Save model & patient embeddings → digital twin representation \
