# %% [markdown]
# # Static Preprocessing

# %%
import pandas as pd
import os
import sys
import json
from pathlib import Path

# Notebook is in notebooks/, so repo root is parent
REPO_ROOT = Path.cwd().parent
SRC_PATH = REPO_ROOT / "src"

# Insert src at the front of sys.path so imports work
sys.path.insert(0, str(SRC_PATH))

# %%
from preprocessing.static_preprocessing import load_static_data

# Get repo root relative to the current notebook
repo_root = os.path.abspath(os.path.join(os.getcwd(), ".."))

# Load static preprocessing config
config_path = os.path.join(repo_root, "configs", "static_preprocessing_params.json")
with open(config_path, "r") as f:
    config = json.load(f)

# Set input and output directories
in_dir = os.path.join(repo_root, config["paths"]["in_dir"])
out_dir = os.path.join(repo_root, config["paths"]["out_dir"])

# Pass in_dir as the first argument
hosp_patients_df, hosp_admissions_df, hosp_diagnosis_df, hosp_drgcodes_df, icustays_df, edstays_df, ed_diagnosis_df, record_list_df = load_static_data(in_dir, config)

# %% [markdown]
# ## Clean ECG Reports

# %%
from preprocessing.static_preprocessing import clean_cols_types

record_list_df_cleaned = clean_cols_types(record_list_df)
record_list_df_cleaned.head()
# Out:
#    subject_id  study_id  file_name            ecg_time  \
# 0    10000032  40689238   40689238 2180-07-23 08:44:00
# 1    10000032  44458630   44458630 2180-07-23 09:54:00
# 2    10000032  49036311   49036311 2180-08-06 09:07:00
# 3    10000117  45090959   45090959 2181-03-04 17:14:00
# 4    10000117  48446569   48446569 2183-09-18 13:52:00
#
#                                        path
# 0  files/p1000/p10000032/s40689238/40689238
# 1  files/p1000/p10000032/s44458630/44458630
# 2  files/p1000/p10000032/s49036311/49036311
# 3  files/p1000/p10000117/s45090959/45090959
# 4  files/p1000/p10000117/s48446569/48446569

# %%
record_list_df_cleaned.dtypes
# Out:
# subject_id             int64
# study_id               int64
# file_name              int64
# ecg_time      datetime64[ns]
# path          string[python]
# dtype: object

# %% [markdown]
# ## Cleaning Hospital Module
#
# ### Hospital Admissions

# %%
from preprocessing.static_preprocessing import preprocess_admissions

hosp_admissions_df_cleaned = preprocess_admissions(hosp_admissions_df)
hosp_admissions_df_cleaned.head()
# Out:
#    subject_id   hadm_id           admittime           dischtime deathtime  \
# 0    10106244  26713233 2147-05-09 10:34:00 2147-05-12 13:43:00       NaT
# 1    13700703  20448599 2172-09-25 01:01:00 2172-10-03 13:25:00       NaT
# 2    15443666  27961368 2168-12-30 23:30:00 2169-01-05 16:02:00       NaT
# 3    16299919  26977065 2193-05-15 08:37:00 2193-05-17 16:03:00       NaT
# 4    14149715  24191358 2181-10-25 19:37:00 2181-10-29 14:38:00       NaT
#
#       admission_type admit_provider_id        discharge_location  \
# 0       DIRECT EMER.              <NA>                      HOME
# 1  OBSERVATION ADMIT              <NA>                      HOME
# 2  OBSERVATION ADMIT              <NA>          HOME HEALTH CARE
# 3  OBSERVATION ADMIT              <NA>                   HOSPICE
# 4  OBSERVATION ADMIT            P00230  SKILLED NURSING FACILITY
#
#                      race           edregtime           edouttime
# 0                   WHITE                 NaT                 NaT
# 1                   WHITE 2172-09-24 17:38:00 2172-09-25 03:07:00
# 2  BLACK/AFRICAN AMERICAN 2168-12-30 11:19:00 2168-12-31 01:22:00
# 3  BLACK/AFRICAN AMERICAN 2193-05-15 04:36:00 2193-05-15 14:27:00
# 4                   WHITE 2181-10-25 08:48:00 2181-10-26 15:18:00

# %%
hosp_admissions_df_cleaned.dtypes
# Out:
# subject_id                     int64
# hadm_id                        int64
# admittime             datetime64[ns]
# dischtime             datetime64[ns]
# deathtime             datetime64[ns]
# admission_type        string[python]
# admit_provider_id     string[python]
# discharge_location    string[python]
# race                  string[python]
# edregtime             datetime64[ns]
# edouttime             datetime64[ns]
# dtype: object

# %% [markdown]
# ### Hopsital Patient

# %%
from preprocessing.static_preprocessing import preprocess_patient

hosp_patients_df_cleaned = preprocess_patient(hosp_patients_df)
hosp_patients_df_cleaned.head()
# Out:
#    subject_id gender  anchor_age dod
# 0    11289691      F          18 NaT
# 1    11806971      F          18 NaT
# 2    12107404      F          18 NaT
# 3    12143996      F          18 NaT
# 4    13117076      F          18 NaT

# %%
hosp_patients_df_cleaned.dtypes
# Out:
# subject_id             int64
# gender        string[python]
# anchor_age             int64
# dod           datetime64[ns]
# dtype: object

# %% [markdown]
# ### Hospital Drgcodes

# %%
from preprocessing.static_preprocessing import preprocess_drgcodes

hosp_drgcodes_df_cleaned = preprocess_drgcodes(hosp_drgcodes_df)
# Out:
#    subject_id   hadm_id drg_type  drg_code description  drg_severity  \
# 0    10004235  22187210     HCFA       864       FEVER           NaN
# 1    10013643  27433745     HCFA       864       FEVER           NaN
# 2    10014610  27408652     HCFA       864       FEVER           NaN
# 3    10014610  28254713     HCFA       864       FEVER           NaN
# 4    10033552  20193539     HCFA       864       FEVER           NaN
#
#    drg_mortality
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN

# %%
hosp_drgcodes_df_cleaned.dtypes
# Out:
# subject_id            int64
# hadm_id               int64
# drg_code_apr         object
# description_apr      object
# drg_severity_apr     object
# drg_mortality_apr    object
# drg_code_hcfa        object
# description_hcfa     object
# dtype: object

# %% [markdown]
# ### Hospital Diagnosis

# %%
hosp_diagnosis_df.head()
# Out:
#    subject_id   hadm_id  seq_num icd_code  icd_version  \
# 0    10000935  26381316       27    78052            9
# 1    10000980  25242409       27    44021            9
# 2    10000980  25242409       28    27800            9
# 3    10000980  25242409       29    V8522            9
# 4    10000980  25242409       30    72992            9
#
#                                           long_title
# 0                              Insomnia, unspecified
# 1  Atherosclerosis of native arteries of the extr...
# 2                               Obesity, unspecified
# 3                   Body Mass Index 26.0-26.9, adult
# 4               Nontraumatic hematoma of soft tissue

# %%
from preprocessing.static_preprocessing import clean_diagnosis_data

hosp_diagnosis_df_cleaned = clean_diagnosis_data(hosp_diagnosis_df, 'hosp')
hosp_diagnosis_df_cleaned.head()
# Out:
#    subject_id   hadm_id                           hosp_icd_codes_diagnosis  \
# 0    10000032  22595853  [5723, 78959, 5715, 07070, 496, 29680, 30981, ...
# 1    10000032  22841357   [07071, 78959, 2875, 2761, 496, 5715, V08, 3051]
# 2    10000032  25742920  [07054, 78959, V462, 5715, 2767, 2761, 496, V0...
# 3    10000032  29079034  [45829, 07044, 7994, 2761, 78959, 2767, 3051, ...
# 4    10000117  22927623  [R1310, R0989, K31819, K219, K449, F419, I341,...
#
#                                       hosp_diagnosis
# 0  [Portal hypertension, Other ascites, Cirrhosis...
# 1  [Unspecified viral hepatitis C with hepatic co...
# 2  [Chronic hepatitis C without mention of hepati...
# 3  [Other iatrogenic hypotension, Chronic hepatit...
# 4  [Dysphagia, unspecified, Other specified sympt...

# %%
hosp_diagnosis_df_cleaned.dtypes
# Out:
# subject_id                   int64
# hadm_id                      int64
# hosp_icd_codes_diagnosis    object
# hosp_diagnosis              object
# dtype: object

# %% [markdown]
# ## ICU

# %%
# from preprocessing.static_preprocessing import preprocess_icustays

def add_prefix_to_columns(df, prefix):
    """
    Add prefix to all columns except subject_id and hadm_id.
    """
    exclude_cols = ['subject_id', 'hadm_id']
    
    rename_dict = {
        col: f"{prefix}_{col}" 
        for col in df.columns 
        if col not in exclude_cols
    }
    
    return clean_cols_types(df.rename(columns=rename_dict))

icustays_df_cleaned = add_prefix_to_columns(icustays_df, 'icu')
icustays_df_cleaned.head()
# Out:
#    subject_id   hadm_id  icu_stay_id icu_first_careunit icu_last_careunit  \
# 0    10270644  20019675     35548343               PACU              PACU
# 1    10368426  21588639     39194905               PACU              PACU
# 2    10640410  25898987     34344828               PACU              PACU
# 3    10691194  24438843     37799251               PACU              PACU
# 4    11162329  26304963     39444424               PACU              PACU
#
#            icu_intime         icu_outtime   icu_los
# 0 2159-12-03 16:20:31 2159-12-08 17:28:42  5.047350
# 1 2164-12-30 13:29:21 2164-12-30 14:00:38  0.021725
# 2 2112-02-03 12:55:23 2112-02-08 15:14:54  5.096887
# 3 2147-06-01 17:38:48 2147-06-01 17:58:44  0.013843
# 4 2137-06-11 19:49:23 2137-06-12 14:54:47  0.795417

# %%
icustays_df_cleaned.dtypes
# Out:
# subject_id                     int64
# hadm_id                        int64
# icu_stay_id                    int64
# icu_first_careunit    string[python]
# icu_last_careunit     string[python]
# icu_intime            datetime64[ns]
# icu_outtime           datetime64[ns]
# icu_los                      float64
# dtype: object

# %% [markdown]
# ## Emergency Department
# ### ED Stays

# %%
edstays_df_cleaned = add_prefix_to_columns(edstays_df, 'ed')
edstays_df_cleaned.head()
# Out:
#    subject_id     hadm_id  ed_stay_id           ed_intime          ed_outtime  \
# 0    10049341  20677333.0    34255415 2171-04-07 17:48:00 2171-04-08 09:31:00
# 1    10049341         NaN    35767475 2170-08-29 18:20:00 2170-08-29 22:46:00
# 2    10049341         NaN    36382949 2171-11-19 20:09:00 2171-11-20 00:03:00
# 3    10049341         NaN    36490047 2174-11-29 19:39:00 2174-11-30 00:49:00
# 4    10049341         NaN    37283116 2174-01-26 20:10:00 2174-01-27 00:34:00
#
#   ed_gender ed_race ed_arrival_transport ed_disposition
# 0         F   ASIAN              WALK IN           HOME
# 1         F   ASIAN              WALK IN           HOME
# 2         F   ASIAN              WALK IN           HOME
# 3         F   ASIAN              WALK IN           HOME
# 4         F   ASIAN              WALK IN           HOME

# %%
edstays_df_cleaned.dtypes
# Out:
# subject_id                       int64
# hadm_id                        float64
# ed_stay_id                       int64
# ed_intime               datetime64[ns]
# ed_outtime              datetime64[ns]
# ed_gender               string[python]
# ed_race                 string[python]
# ed_arrival_transport    string[python]
# ed_disposition          string[python]
# dtype: object

# %% [markdown]
# ### ED Diagnosis

# %%
ed_diagnosis_df_cleaned = clean_diagnosis_data(ed_diagnosis_df, 'ed')
ed_diagnosis_df_cleaned.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/bn/28hly9dd0z36556zl0gx44v80000gn/T/ipykernel_14906/1024551985.py in ?()
# ----> 1 ed_diagnosis_df_cleaned = clean_diagnosis_data(ed_diagnosis_df)
#       2 ed_diagnosis_df_cleaned.head()
#
# ~/Documents/GitHub/ClinicalDigitalTwin/src/preprocessing/static_preprocessing.py in ?(df)
#
# ~/miniforge3/envs/dsc180/lib/python3.14/site-packages/pandas/core/frame.py in ?(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    7190                 f"Length of ascending ({len(ascending)})"  # type: ignore[arg-type]
#    7191                 f" != length of by ({len(by)})"
#    7192             )
#    7193         if len(by) > 1:
# -> 7194             keys = [self._get_label_or_level_values(x, axis=axis) for x in by]
#    7195
#    7196             # need to rewrap columns in Series to apply key function
#    7197             if key is not None:
#
# ~/miniforge3/envs/dsc180/lib/python3.14/site-packages/pandas/core/generic.py in ?(self, key, axis)
#    1910             values = self.xs(key, axis=other_axes[0])._values
#    1911         elif self._is_level_reference(key, axis=axis):
#    1912             values = self.axes[axis].get_level_values(key)._values
#    1913         else:
# -> 1914             raise KeyError(key)
#    1915
#    1916         # Check for duplicates
#    1917         if values.ndim > 1:
#
# KeyError: 'hadm_id'

# %%
ed_diagnosis_df.head()
# Out:
#    subject_id   stay_id  seq_num icd_code  icd_version    icd_title
# 0    16253470  37248432        1      035            9   ERYSIPELAS
# 1    10396349  36517744        1      042            9  HIV DISEASE
# 2    10429665  38305760        1      042            9  HIV DISEASE
# 3    10446182  31712472        1      042            9  HIV DISEASE
# 4    11053554  34764404        1      042            9  HIV DISEASE

# %% [markdown]
# ## Merge Hospital, ICU, and ED Data

# %%
df_hosp_patient = df_hosp_admissions_cleaned.merge(df_hosp_patient_cleaned, on="subject_id")
df_hosp_patient['death_time'] = df_hosp_patient['deathtime'].combine_first(df_hosp_patient['dod'])
df_hosp_patient.drop(columns=['dod', 'deathtime'], inplace=True)
df_hosp_patient.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 df_hosp_patient = df_hosp_admissions_cleaned.merge(df_hosp_patient_cleaned, on="subject_id")
#       2 df_hosp_patient['death_time'] = df_hosp_patient['deathtime'].combine_first(df_hosp_patient['dod'])
#       3 df_hosp_patient.drop(columns=['dod', 'deathtime'], inplace=True)
#
# NameError: name 'df_hosp_admissions_cleaned' is not defined

# %%
df_hosp_patient.shape
# Out:
# (395931, 13)

# %%
# missing values only because no diagnosis maybe in icu or ed?

df_hosp_patient_diag = df_hosp_patient.merge(df_diagnosis_cleaned, on=["subject_id", "hadm_id"], how="left")
df_hosp_patient_diag
# Out:
#         subject_id   hadm_id           admittime           dischtime  \
# 0         10106244  26713233 2147-05-09 10:34:00 2147-05-12 13:43:00
# 1         13700703  20448599 2172-09-25 01:01:00 2172-10-03 13:25:00
# 2         15443666  27961368 2168-12-30 23:30:00 2169-01-05 16:02:00
# 3         16299919  26977065 2193-05-15 08:37:00 2193-05-17 16:03:00
# 4         14149715  24191358 2181-10-25 19:37:00 2181-10-29 14:38:00
# ...            ...       ...                 ...                 ...
# 395926    16711441  22500229 2179-11-16 17:15:00 2179-11-18 12:45:00
# 395927    18766758  25415341 2131-12-08 18:55:00 2131-12-12 16:15:00
# 395928    11286186  23566382 2157-04-08 09:15:00 2157-04-09 17:00:00
# 395929    16578860  26155863 2150-12-07 03:38:00 2150-12-08 16:11:00
# 395930    15916117  20589369 2144-01-18 02:02:00 2144-01-21 18:40:00
#
#                      admission_type admit_provider_id  \
# 0                      DIRECT EMER.              <NA>
# 1                 OBSERVATION ADMIT              <NA>
# 2                 OBSERVATION ADMIT              <NA>
# 3                 OBSERVATION ADMIT              <NA>
# 4                 OBSERVATION ADMIT            P00230
# ...                             ...               ...
# 395926            OBSERVATION ADMIT            P99Z33
# 395927            OBSERVATION ADMIT            P99Z33
# 395928           DIRECT OBSERVATION            P99Z33
# 395929           DIRECT OBSERVATION            P99Z33
# 395930  SURGICAL SAME DAY ADMISSION            P99Z33
#
#               discharge_location                         race  \
# 0                           HOME                        WHITE
# 1                           HOME                        WHITE
# 2               HOME HEALTH CARE       BLACK/AFRICAN AMERICAN
# 3                        HOSPICE       BLACK/AFRICAN AMERICAN
# 4       SKILLED NURSING FACILITY                        WHITE
# ...                          ...                          ...
# 395926          HOME HEALTH CARE  HISPANIC/LATINO - DOMINICAN
# 395927          HOME HEALTH CARE                        WHITE
# 395928                      <NA>                        WHITE
# 395929                      <NA>  HISPANIC/LATINO - DOMINICAN
# 395930                     REHAB                        WHITE
#
#                  edregtime           edouttime gender  anchor_age death_time  \
# 0                      NaT                 NaT      F          60        NaT
# 1      2172-09-24 17:38:00 2172-09-25 03:07:00      F          56        NaT
# 2      2168-12-30 11:19:00 2168-12-31 01:22:00      F          75 2175-03-01
# 3      2193-05-15 04:36:00 2193-05-15 14:27:00      F          91 2194-02-03
# 4      2181-10-25 08:48:00 2181-10-26 15:18:00      F          64 2186-05-01
# ...                    ...                 ...    ...         ...        ...
# 395926 2179-11-16 12:06:00 2179-11-16 19:06:00      M          58        NaT
# 395927 2131-12-08 14:28:00 2131-12-08 19:46:00      M          34        NaT
# 395928                 NaT                 NaT      F          49        NaT
# 395929                 NaT                 NaT      M          64        NaT
# 395930                 NaT                 NaT      F          61        NaT
#
#                                  hosp_icd_codes_diagnosis  \
# 0       [I25110, I2542, I501, T82593A, J9811, I9589, Y...
# 1       [K224, R1013, E039, G4733, G894, D72829, Y848,...
# 2       [T82538A, E1140, I509, I482, I10, I714, K5900,...
# 3       [I120, N179, N185, E1121, F0390, Z794, Z87891,...
# 4       [S12120A, I4891, W109XXA, Y92009, I10, E785, I...
# ...                                                   ...
# 395926  [L02612, L03116, I10, E119, S90872A, E785, W57...
# 395927  [E11621, L97511, M216X1, L97421, L03115, Z9481...
# 395928  [S92341A, S92351A, W19XXXA, Y929, G40802, K219...
# 395929  [M86171, I70261, I10, F17210, Z7902, Z95828, E...
# 395930  [M24575, E1151, E11621, I10, E119, R339, Z8789...
#
#                                            hosp_diagnosis
# 0       [Atherosclerotic heart disease of native coron...
# 1       [Dyskinesia of esophagus, Epigastric pain, Hyp...
# 2       [Leakage of other cardiac and vascular devices...
# 3       [Hypertensive chronic kidney disease with stag...
# 4       [Other displaced dens fracture, initial encoun...
# ...                                                   ...
# 395926  [Cutaneous abscess of left foot, Cellulitis of...
# 395927  [Type 2 diabetes mellitus with foot ulcer, Non...
# 395928  [Displaced fracture of fourth metatarsal bone,...
# 395929  [Other acute osteomyelitis, right ankle and fo...
# 395930  [Contracture, left foot, Type 2 diabetes melli...
#
# [395931 rows x 15 columns]
